# %%
import pandas as pd
import numpy as np

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import os
plt.style.use('fivethirtyeight')
plt.rcParams["figure.figsize"] = (8, 6)

# %%
os.getcwd()
# Out:
# '/home/jovyan/졸업작품/UNLV_Project'

# %%
base_path = "Dataset/heg_sample_data.csv"

dataset = pd.read_csv(base_path)

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13652 entries, 0 to 13651
# Data columns (total 73 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              13652 non-null  int64
#  1   days_from_entrance                      13652 non-null  float64
#  2   age                                     13652 non-null  float64
#  3   document.sexo                           13652 non-null  float64
#  4   UTI                                     13652 non-null  float64
#  5   delta_collect_timestamp_t-t1            13652 non-null  float64
#  6   delta_collect_timestamp_t1-t2           13652 non-null  float64
#  7   delta_collect_timestamp_t2-t3           13652 non-null  float64
#  8   delta_collect_timestamp_t3-t4           13652 non-null  float64
#  9   document.freq_cardiaca(t)               13652 non-null  float64
#  10  document.freq_cardiaca(t-1)             13652 non-null  float64
#  11  document.freq_cardiaca(t-2)             13652 non-null  float64
#  12  document.freq_cardiaca(t-3)             13652 non-null  float64
#  13  document.freq_cardiaca(t-4)             13652 non-null  float64
#  14  document.freq_respiratoria(t)           13652 non-null  float64
#  15  document.freq_respiratoria(t-1)         13652 non-null  float64
#  16  document.freq_respiratoria(t-2)         13652 non-null  float64
#  17  document.freq_respiratoria(t-3)         13652 non-null  float64
#  18  document.freq_respiratoria(t-4)         13652 non-null  float64
#  19  document.glicemia_capilar(t)            13652 non-null  float64
#  20  document.glicemia_capilar(t-1)          13652 non-null  float64
#  21  document.glicemia_capilar(t-2)          13652 non-null  float64
#  22  document.glicemia_capilar(t-3)          13652 non-null  float64
#  23  document.glicemia_capilar(t-4)          13652 non-null  float64
#  24  document.pa_diastolica(t)               13652 non-null  float64
#  25  document.pa_diastolica(t-1)             13652 non-null  float64
#  26  document.pa_diastolica(t-2)             13652 non-null  float64
#  27  document.pa_diastolica(t-3)             13652 non-null  float64
#  28  document.pa_diastolica(t-4)             13652 non-null  float64
#  29  document.pa_sistolica(t)                13652 non-null  float64
#  30  document.pa_sistolica(t-1)              13652 non-null  float64
#  31  document.pa_sistolica(t-2)              13652 non-null  float64
#  32  document.pa_sistolica(t-3)              13652 non-null  float64
#  33  document.pa_sistolica(t-4)              13652 non-null  float64
#  34  document.sat_o2(t)                      13652 non-null  float64
#  35  document.sat_o2(t-1)                    13652 non-null  float64
#  36  document.sat_o2(t-2)                    13652 non-null  float64
#  37  document.sat_o2(t-3)                    13652 non-null  float64
#  38  document.sat_o2(t-4)                    13652 non-null  float64
#  39  document.temperatura(t)                 13652 non-null  float64
#  40  document.temperatura(t-1)               13652 non-null  float64
#  41  document.temperatura(t-2)               13652 non-null  float64
#  42  document.temperatura(t-3)               13652 non-null  float64
#  43  document.temperatura(t-4)               13652 non-null  float64
#  44  delta_document.freq_cardiaca_t-t1       13652 non-null  float64
#  45  delta_document.freq_cardiaca_t1-t2      13652 non-null  float64
#  46  delta_document.freq_cardiaca_t2-t3      13652 non-null  float64
#  47  delta_document.freq_cardiaca_t3-t4      13652 non-null  float64
#  48  delta_document.freq_respiratoria_t-t1   13652 non-null  float64
#  49  delta_document.freq_respiratoria_t1-t2  13652 non-null  float64
#  50  delta_document.freq_respiratoria_t2-t3  13652 non-null  float64
#  51  delta_document.freq_respiratoria_t3-t4  13652 non-null  float64
#  52  delta_document.glicemia_capilar_t-t1    13652 non-null  float64
#  53  delta_document.glicemia_capilar_t1-t2   13652 non-null  float64
#  54  delta_document.glicemia_capilar_t2-t3   13652 non-null  float64
#  55  delta_document.glicemia_capilar_t3-t4   13652 non-null  float64
#  56  delta_document.pa_diastolica_t-t1       13652 non-null  float64
#  57  delta_document.pa_diastolica_t1-t2      13652 non-null  float64
#  58  delta_document.pa_diastolica_t2-t3      13652 non-null  float64
#  59  delta_document.pa_diastolica_t3-t4      13652 non-null  float64
#  60  delta_document.pa_sistolica_t-t1        13652 non-null  float64
#  61  delta_document.pa_sistolica_t1-t2       13652 non-null  float64
#  62  delta_document.pa_sistolica_t2-t3       13652 non-null  float64
#  63  delta_document.pa_sistolica_t3-t4       13652 non-null  float64
#  64  delta_document.sat_o2_t-t1              13652 non-null  float64
#  65  delta_document.sat_o2_t1-t2             13652 non-null  float64
#  66  delta_document.sat_o2_t2-t3             13652 non-null  float64
#  67  delta_document.sat_o2_t3-t4             13652 non-null  float64
#  68  delta_document.temperatura_t-t1         13652 non-null  float64
#  69  delta_document.temperatura_t1-t2        13652 non-null  float64
#  70  delta_document.temperatura_t2-t3        13652 non-null  float64
#  71  delta_document.temperatura_t3-t4        13652 non-null  float64
#  72  outcome                                 13652 non-null  float64
# dtypes: float64(72), int64(1)
# memory usage: 7.6 MB

# %%
#Every features has no NaN.
for col in dataset.columns:
    print(f"{col} feature has the number of NaN value {dataset[col].isna().sum()}")
# Out:
# Unnamed: 0 feature has the number of NaN value 0
# days_from_entrance feature has the number of NaN value 0
# age feature has the number of NaN value 0
# document.sexo feature has the number of NaN value 0
# UTI feature has the number of NaN value 0
# delta_collect_timestamp_t-t1 feature has the number of NaN value 0
# delta_collect_timestamp_t1-t2 feature has the number of NaN value 0
# delta_collect_timestamp_t2-t3 feature has the number of NaN value 0
# delta_collect_timestamp_t3-t4 feature has the number of NaN value 0
# document.freq_cardiaca(t) feature has the number of NaN value 0
# document.freq_cardiaca(t-1) feature has the number of NaN value 0
# document.freq_cardiaca(t-2) feature has the number of NaN value 0
# document.freq_cardiaca(t-3) feature has the number of NaN value 0
# document.freq_cardiaca(t-4) feature has the number of NaN value 0
# document.freq_respiratoria(t) feature has the number of NaN value 0
# document.freq_respiratoria(t-1) feature has the number of NaN value 0
# document.freq_respiratoria(t-2) feature has the number of NaN value 0
# document.freq_respiratoria(t-3) feature has the number of NaN value 0
# document.freq_respiratoria(t-4) feature has the number of NaN value 0
# document.glicemia_capilar(t) feature has the number of NaN value 0
# document.glicemia_capilar(t-1) feature has the number of NaN value 0
# document.glicemia_capilar(t-2) feature has the number of NaN value 0
# document.glicemia_capilar(t-3) feature has the number of NaN value 0
# document.glicemia_capilar(t-4) feature has the number of NaN value 0
# document.pa_diastolica(t) feature has the number of NaN value 0
# document.pa_diastolica(t-1) feature has the number of NaN value 0
# document.pa_diastolica(t-2) feature has the number of NaN value 0
# document.pa_diastolica(t-3) feature has the number of NaN value 0
# document.pa_diastolica(t-4) feature has the number of NaN value 0
# document.pa_sistolica(t) feature has the number of NaN value 0
# document.pa_sistolica(t-1) feature has the number of NaN value 0
# document.pa_sistolica(t-2) feature has the number of NaN value 0
# document.pa_sistolica(t-3) feature has the number of NaN value 0
# document.pa_sistolica(t-4) feature has the number of NaN value 0
# document.sat_o2(t) feature has the number of NaN value 0
# document.sat_o2(t-1) feature has the number of NaN value 0
# document.sat_o2(t-2) feature has the number of NaN value 0
# document.sat_o2(t-3) feature has the number of NaN value 0
# document.sat_o2(t-4) feature has the number of NaN value 0
# document.temperatura(t) feature has the number of NaN value 0
# document.temperatura(t-1) feature has the number of NaN value 0
# document.temperatura(t-2) feature has the number of NaN value 0
# document.temperatura(t-3) feature has the number of NaN value 0
# document.temperatura(t-4) feature has the number of NaN value 0
# delta_document.freq_cardiaca_t-t1 feature has the number of NaN value 0
# delta_document.freq_cardiaca_t1-t2 feature has the number of NaN value 0
# delta_document.freq_cardiaca_t2-t3 feature has the number of NaN value 0
# delta_document.freq_cardiaca_t3-t4 feature has the number of NaN value 0
# delta_document.freq_respiratoria_t-t1 feature has the number of NaN value 0
# delta_document.freq_respiratoria_t1-t2 feature has the number of NaN value 0
# delta_document.freq_respiratoria_t2-t3 feature has the number of NaN value 0
# delta_document.freq_respiratoria_t3-t4 feature has the number of NaN value 0
# delta_document.glicemia_capilar_t-t1 feature has the number of NaN value 0
# delta_document.glicemia_capilar_t1-t2 feature has the number of NaN value 0
# delta_document.glicemia_capilar_t2-t3 feature has the number of NaN value 0
# delta_document.glicemia_capilar_t3-t4 feature has the number of NaN value 0
# delta_document.pa_diastolica_t-t1 feature has the number of NaN value 0
# delta_document.pa_diastolica_t1-t2 feature has the number of NaN value 0
# delta_document.pa_diastolica_t2-t3 feature has the number of NaN value 0
# delta_document.pa_diastolica_t3-t4 feature has the number of NaN value 0
# delta_document.pa_sistolica_t-t1 feature has the number of NaN value 0
# delta_document.pa_sistolica_t1-t2 feature has the number of NaN value 0
# delta_document.pa_sistolica_t2-t3 feature has the number of NaN value 0
# delta_document.pa_sistolica_t3-t4 feature has the number of NaN value 0
# delta_document.sat_o2_t-t1 feature has the number of NaN value 0
# delta_document.sat_o2_t1-t2 feature has the number of NaN value 0
# delta_document.sat_o2_t2-t3 feature has the number of NaN value 0
# delta_document.sat_o2_t3-t4 feature has the number of NaN value 0
# delta_document.temperatura_t-t1 feature has the number of NaN value 0
# delta_document.temperatura_t1-t2 feature has the number of NaN value 0
# delta_document.temperatura_t2-t3 feature has the number of NaN value 0
# delta_document.temperatura_t3-t4 feature has the number of NaN value 0
# outcome feature has the number of NaN value 0
